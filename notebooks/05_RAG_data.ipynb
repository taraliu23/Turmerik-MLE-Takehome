# %%
import pandas as pd

df = pd.read_parquet(
    "hf://datasets/MeetX/mental-health-dataset-mistral7b/data/train-00000-of-00001.parquet")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/opt/anaconda3/envs/city8/lib/python3.10/site-packages/fsspec/registry.py:242, in get_filesystem_class(protocol)
#     241 try:
# --> 242     register_implementation(protocol, _import_class(bit["class"]))
#     243 except ImportError as e:
#
# File ~/opt/anaconda3/envs/city8/lib/python3.10/site-packages/fsspec/registry.py:277, in _import_class(fqp)
#     276 is_s3 = mod == "s3fs"
# --> 277 mod = importlib.import_module(mod)
#     278 if is_s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File ~/opt/anaconda3/envs/city8/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# ...
